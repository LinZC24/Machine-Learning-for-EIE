# %%
import gymnasium as gym
import time
import matplotlib.pyplot as plt
test_envs={'control': 'CartPole-v1'}
game_name=test_envs['control']

env=gym.make(game_name, render_mode='human')
for i_episode in range(1):
  observation=env.reset()
  for t in range(10000):
    env.render()
    print(observation)
    action=env.action_space.sample()
    result = env.step(action)
    print(result)
    observation, reward, done, info, m = result
    if done:
      print('Episode finished after {} timesteps'.format(t+1))
      break
# Out:
# (array([ 0.00338165, -0.03858906, -0.0282165 , -0.00797996], dtype=float32), {})
# (array([ 0.00260987,  0.15692595, -0.0283761 , -0.3094303 ], dtype=float32), 1.0, False, False, {})
# [ 0.00260987  0.15692595 -0.0283761  -0.3094303 ]
# (array([ 0.00574839, -0.03778045, -0.0345647 , -0.02582972], dtype=float32), 1.0, False, False, {})
# [ 0.00574839 -0.03778045 -0.0345647  -0.02582972]
# (array([ 0.00499278, -0.2323901 , -0.0350813 ,  0.2557504 ], dtype=float32), 1.0, False, False, {})
# [ 0.00499278 -0.2323901  -0.0350813   0.2557504 ]
# (array([ 3.4497469e-04, -4.2699406e-01, -2.9966291e-02,  5.3716499e-01],
#       dtype=float32), 1.0, False, False, {})
# [ 3.4497469e-04 -4.2699406e-01 -2.9966291e-02  5.3716499e-01]
# (array([-0.00819491, -0.62168217, -0.01922299,  0.82025725], dtype=float32), 1.0, False, False, {})
# [-0.00819491 -0.62168217 -0.01922299  0.82025725]
# (array([-0.02062855, -0.81653583, -0.00281785,  1.1068325 ], dtype=float32), 1.0, False, False, {})
# [-0.02062855 -0.81653583 -0.00281785  1.1068325 ]
# (array([-0.03695927, -0.621377  ,  0.0193188 ,  0.81326693], dtype=float32), 1.0, False, False, {})
# [-0.03695927 -0.621377    0.0193188   0.81326693]
# (array([-0.04938681, -0.42652485,  0.03558414,  0.52672267], dtype=float32), 1.0, False, False, {})
# [-0.04938681 -0.42652485  0.03558414  0.52672267]
# (array([-0.0579173 , -0.2319212 ,  0.04611859,  0.24546151], dtype=float32), 1.0, False, False, {})
# [-0.0579173  -0.2319212   0.04611859  0.24546151]
# (array([-0.06255573, -0.03748725,  0.05102783, -0.03232525], dtype=float32), 1.0, False, False, {})
# [-0.06255573 -0.03748725  0.05102783 -0.03232525]
# (array([-0.06330547,  0.15686722,  0.05038132, -0.3084818 ], dtype=float32), 1.0, False, False, {})
# [-0.06330547  0.15686722  0.05038132 -0.3084818 ]
# (array([-0.06016813, -0.03893505,  0.04421169, -0.00034524], dtype=float32), 1.0, False, False, {})
# [-0.06016813 -0.03893505  0.04421169 -0.00034524]
# (array([-0.06094683,  0.15552588,  0.04420478, -0.2787576 ], dtype=float32), 1.0, False, False, {})
# [-0.06094683  0.15552588  0.04420478 -0.2787576 ]
# (array([-0.05783631,  0.34999025,  0.03862963, -0.55717725], dtype=float32), 1.0, False, False, {})
# [-0.05783631  0.34999025  0.03862963 -0.55717725]
# (array([-0.05083651,  0.1543479 ,  0.02748608, -0.25257835], dtype=float32), 1.0, False, False, {})
# [-0.05083651  0.1543479   0.02748608 -0.25257835]
# (array([-0.04774955,  0.3490668 ,  0.02243452, -0.5364665 ], dtype=float32), 1.0, False, False, {})
# [-0.04774955  0.3490668   0.02243452 -0.5364665 ]
# (array([-0.04076821,  0.15363671,  0.01170519, -0.23679993], dtype=float32), 1.0, False, False, {})
# [-0.04076821  0.15363671  0.01170519 -0.23679993]
# (array([-0.03769548,  0.3485895 ,  0.00696919, -0.5257678 ], dtype=float32), 1.0, False, False, {})
# [-0.03769548  0.3485895   0.00696919 -0.5257678 ]
# (array([-0.03072369,  0.5436127 , -0.00354617, -0.81624657], dtype=float32), 1.0, False, False, {})
# [-0.03072369  0.5436127  -0.00354617 -0.81624657]
# (array([-0.01985143,  0.34853947, -0.0198711 , -0.52468115], dtype=float32), 1.0, False, False, {})
# [-0.01985143  0.34853947 -0.0198711  -0.52468115]
# (array([-0.01288064,  0.15370272, -0.03036472, -0.23832545], dtype=float32), 1.0, False, False, {})
# [-0.01288064  0.15370272 -0.03036472 -0.23832545]
# (array([-0.00980659, -0.04097258, -0.03513123,  0.04462703], dtype=float32), 1.0, False, False, {})
# [-0.00980659 -0.04097258 -0.03513123  0.04462703]
# (array([-0.01062604,  0.15463506, -0.03423869, -0.25892985], dtype=float32), 1.0, False, False, {})
# [-0.01062604  0.15463506 -0.03423869 -0.25892985]
# (array([-0.00753334,  0.35022867, -0.03941729, -0.56221247], dtype=float32), 1.0, False, False, {})
# [-0.00753334  0.35022867 -0.03941729 -0.56221247]
# (array([-5.2876741e-04,  5.4588091e-01, -5.0661538e-02, -8.6704862e-01],
#       dtype=float32), 1.0, False, False, {})
# [-5.2876741e-04  5.4588091e-01 -5.0661538e-02 -8.6704862e-01]
# (array([ 0.01038885,  0.74165434, -0.06800251, -1.1752201 ], dtype=float32), 1.0, False, False, {})
# [ 0.01038885  0.74165434 -0.06800251 -1.1752201 ]
# (array([ 0.02522194,  0.9375908 , -0.09150691, -1.4884228 ], dtype=float32), 1.0, False, False, {})
# [ 0.02522194  0.9375908  -0.09150691 -1.4884228 ]
# (array([ 0.04397376,  0.74369484, -0.12127537, -1.2256612 ], dtype=float32), 1.0, False, False, {})
# [ 0.04397376  0.74369484 -0.12127537 -1.2256612 ]
# (array([ 0.05884765,  0.5503249 , -0.1457886 , -0.97330433], dtype=float32), 1.0, False, False, {})
# [ 0.05884765  0.5503249  -0.1457886  -0.97330433]
# (array([ 0.06985415,  0.7470701 , -0.16525468, -1.3080016 ], dtype=float32), 1.0, False, False, {})
# [ 0.06985415  0.7470701  -0.16525468 -1.3080016 ]
# (array([ 0.08479555,  0.5543822 , -0.19141471, -1.0712714 ], dtype=float32), 1.0, False, False, {})
# [ 0.08479555  0.5543822  -0.19141471 -1.0712714 ]
# (array([ 0.09588319,  0.3622347 , -0.21284014, -0.84424716], dtype=float32), 1.0, True, False, {})
# Episode finished after 32 timesteps
